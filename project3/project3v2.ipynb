# %% [markdown]
# ## Project 3
# #### Name Gender Predictor
#
# ##### Maxfield Raynolds
# ##### Data 620
# ##### Spring 2026

# %% [markdown]
# Import necessary packages and name list.

# %%
import nltk
import random
from nltk.corpus import names

# %% [markdown]
# Create a list of labeled names.

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

# %% [markdown]
# Shuffle the name list.

# %%
random.seed(1234)
random.shuffle(labeled_names)

# %% [markdown]
# #### Possible variables in a name:
#
# To create a name gender predictor, it will be necessary to enter features that will aid in a model being more successful at predicting the gender commonly associated with a name. In order to execute this task, it is worthwhile to narrow down possible variables that an algorithm could use. Below is a list of possible variables:
#
# - Name length
# - Starting letters (1 to n letters from the beginning of the name)
# - Ending letters (1 to n letters from the end of the name)
# - Specific letters
# - Count of letters
# - Specific position of letters
# - Specific grouping of consonants (as in do specific sets of consonants play a role)
#
# While this list is not exhaustive, it covers many possibilities.

# %% [markdown]
# #### Testing the first variable
#
# Below, over the course of three code blocks, the first variable: length, will be tested.
#
# Create a function to start testing variables:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)

    return features

# %% [markdown]
# Then we will create the featuresets:

# %%
featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

# %% [markdown]
# Finally, we will instantiate the NaiveBayesClassifer, train it and test it against the dev_test_set.

# %%
Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(
    f'Bayes acuracy {Bayes_accuracy}'
    f'Max entropy accuracy {Max_accuracy}'
    f'Tree accuracy {Tree_accuracy}'
)
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.61876        0.634
#              3          -0.61874        0.634
#              4          -0.61872        0.634
#              5          -0.61872        0.634
#              6          -0.61871        0.634
#              7          -0.61870        0.634
#              8          -0.61870        0.634
#              9          -0.61870        0.634
#             10          -0.61870        0.634
#             11          -0.61869        0.634
#             12          -0.61869        0.634
#             13          -0.61869        0.634
#             14          -0.61869        0.634
#             15          -0.61869        0.634
#             16          -0.61869        0.634
#             17          -0.61869        0.634
#             18          -0.61868        0.634
# ...

# %% [markdown]
# This results in a 64% accuracy, or just under 2/3rds correct. There is clearly room for improvement. Below, the featureset will be expanded and various iterations run to test the accuracy. The three previous code blocks will be combined for efficiency.

# %% [markdown]
# First is to check the addition of the last letter.

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    #features['last_two_letters'] = name[-2:]
    #features['first_two_letters'] = name[:2]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.44421        0.753
#              3          -0.40104        0.770
#              4          -0.38473        0.767
#              5          -0.37746        0.766
#              6          -0.37392        0.766
#              7          -0.37209        0.766
#              8          -0.37109        0.766
#              9          -0.37052        0.765
#             10          -0.37018        0.765
#             11          -0.36995        0.765
#             12          -0.36980        0.765
#             13          -0.36970        0.765
#             14          -0.36962        0.765
#             15          -0.36955        0.765
#             16          -0.36950        0.765
#             17          -0.36946        0.765
#             18          -0.36943        0.765
# ...

# %% [markdown]
# This improves the prediction significantly now on all three classifiers.

# %%
def gender_features(name):
    features = {}
    #features['name_length'] = len(name)
    features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    #features['last_two_letters'] = name[-2:]
    #features['first_two_letters'] = name[:2]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.37245        0.762
#              3          -0.37210        0.762
#              4          -0.37189        0.762
#              5          -0.37175        0.762
#              6          -0.37165        0.762
#              7          -0.37158        0.762
#              8          -0.37152        0.762
#              9          -0.37147        0.762
#             10          -0.37144        0.762
#             11          -0.37140        0.762
#             12          -0.37138        0.762
#             13          -0.37135        0.762
#             14          -0.37133        0.762
#             15          -0.37132        0.762
#             16          -0.37130        0.762
#             17          -0.37129        0.762
#             18          -0.37128        0.762
# ...

# %% [markdown]
# At 75.6%, it turns out length is helping. Now what if we include the first letter:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    features['last_letter'] = name[-1]
    features['first_letter'] = name[0]
    #features['last_two_letters'] = name[-2:]
    #features['first_two_letters'] = name[:2]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.47595        0.737
#              3          -0.41920        0.778
#              4          -0.39134        0.780
#              5          -0.37594        0.782
#              6          -0.36663        0.784
#              7          -0.36064        0.784
#              8          -0.35663        0.784
#              9          -0.35384        0.786
#             10          -0.35186        0.785
#             11          -0.35042        0.785
#             12          -0.34935        0.785
#             13          -0.34855        0.785
#             14          -0.34793        0.785
#             15          -0.34745        0.785
#             16          -0.34707        0.785
#             17          -0.34677        0.785
#             18          -0.34653        0.785
# ...

# %% [markdown]
# Interestingly this is not much different than when we had not included the first letter. Let's remove it and then add in the last two letters:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    #features['first_two_letters'] = name[:2]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.38991        0.789
#              3          -0.34879        0.797
#              4          -0.33291        0.799
#              5          -0.32480        0.802
#              6          -0.31995        0.804
#              7          -0.31672        0.805
#              8          -0.31443        0.805
#              9          -0.31272        0.805
#             10          -0.31140        0.805
#             11          -0.31035        0.805
#             12          -0.30950        0.805
#             13          -0.30879        0.805
#             14          -0.30819        0.805
#             15          -0.30767        0.805
#             16          -0.30722        0.805
#             17          -0.30682        0.805
#             18          -0.30646        0.805
# ...

# %% [markdown]
# This is incrementally better. However, could considering both the last letter and the last two letters as independent features be limiting the model? Let's see:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    #features['first_two_letters'] = name[:2]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.42094        0.782
#              3          -0.37091        0.804
#              4          -0.34974        0.805
#              5          -0.33863        0.805
#              6          -0.33196        0.805
#              7          -0.32754        0.805
#              8          -0.32437        0.805
#              9          -0.32196        0.805
#             10          -0.32004        0.805
#             11          -0.31846        0.805
#             12          -0.31711        0.805
#             13          -0.31595        0.805
#             14          -0.31494        0.805
#             15          -0.31405        0.805
#             16          -0.31325        0.805
#             17          -0.31254        0.805
#             18          -0.31189        0.805
# ...

# %% [markdown]
# Doing better still. While the first letter was not helpful, perhaps the first two would be useful.

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    features['first_two_letters'] = name[:2]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.44019        0.768
#              3          -0.37676        0.819
#              4          -0.34536        0.827
#              5          -0.32693        0.831
#              6          -0.31484        0.833
#              7          -0.30628        0.834
#              8          -0.29990        0.836
#              9          -0.29494        0.837
#             10          -0.29097        0.838
#             11          -0.28770        0.839
#             12          -0.28496        0.839
#             13          -0.28261        0.839
#             14          -0.28058        0.840
#             15          -0.27880        0.840
#             16          -0.27722        0.840
#             17          -0.27581        0.839
#             18          -0.27454        0.840
# ...

# %% [markdown]
# Incrementally better still.  Let's now include, a count of each letter used in each name:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    features['first_two_letters'] = name[:2]
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.59546        0.631
#              3          -0.56993        0.632
#              4          -0.54684        0.656
#              5          -0.52605        0.697
#              6          -0.50736        0.726
#              7          -0.49056        0.749
#              8          -0.47546        0.769
#              9          -0.46186        0.782
#             10          -0.44959        0.792
#             11          -0.43847        0.801
#             12          -0.42839        0.808
#             13          -0.41921        0.814
#             14          -0.41083        0.817
#             15          -0.40315        0.819
#             16          -0.39610        0.821
#             17          -0.38961        0.823
#             18          -0.38362        0.825
# ...

# %% [markdown]
# This was not especially useful. How about whether a letter exists in the name:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    features['first_two_letters'] = name[:2]
    for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
       features['has({})'.format(letter)] = (letter in name.lower())
    #    features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.59768        0.631
#              3          -0.57376        0.631
#              4          -0.55192        0.651
#              5          -0.53209        0.685
#              6          -0.51412        0.717
#              7          -0.49786        0.742
#              8          -0.48314        0.759
#              9          -0.46980        0.773
#             10          -0.45769        0.786
#             11          -0.44669        0.793
#             12          -0.43665        0.800
#             13          -0.42749        0.806
#             14          -0.41910        0.811
#             15          -0.41139        0.814
#             16          -0.40430        0.817
#             17          -0.39775        0.818
#             18          -0.39170        0.820
# ...

# %% [markdown]
# This was slightly better still. Finally, let's see if a letter position helps:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    features['first_two_letters'] = name[:2]
    for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
        features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.59151        0.631
#              3          -0.56284        0.639
#              4          -0.53730        0.680
#              5          -0.51464        0.721
#              6          -0.49460        0.753
#              7          -0.47685        0.769
#              8          -0.46111        0.782
#              9          -0.44710        0.791
#             10          -0.43459        0.801
#             11          -0.42337        0.808
#             12          -0.41328        0.812
#             13          -0.40416        0.816
#             14          -0.39588        0.819
#             15          -0.38835        0.821
#             16          -0.38147        0.824
#             17          -0.37516        0.827
#             18          -0.36935        0.829
# ...

# %% [markdown]
# Again this is incrementally better. So the best result on the dev_test_set has been a combination of:
#
# - length
# - the first two letters
# - the last two letters
# - letter position
#
# What if we consider more letters such as the first three and last three:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    features['first_two_letters'] = name[:2]
    features['last_three_letters'] = name[-3:]
    features['first_three_letters'] = name[:3]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #   features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.40272        0.831
#              3          -0.32773        0.872
#              4          -0.28930        0.883
#              5          -0.26525        0.893
#              6          -0.24834        0.898
#              7          -0.23553        0.903
#              8          -0.22535        0.906
#              9          -0.21697        0.908
#             10          -0.20989        0.911
#             11          -0.20379        0.913
#             12          -0.19846        0.915
#             13          -0.19375        0.916
#             14          -0.18954        0.917
#             15          -0.18574        0.917
#             16          -0.18230        0.918
#             17          -0.17916        0.919
#             18          -0.17628        0.919
# ...

# %% [markdown]
# The best result yet. Interestingly, this result does not decline if the first two letters are removed as a feature:

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    #features['first_two_letters'] = name[:2]
    features['last_three_letters'] = name[-3:]
    features['first_three_letters'] = name[:3]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #   features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, dev_test_set)
Max_accuracy = nltk.classify.accuracy(Max, dev_test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, dev_test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.38049        0.844
#              3          -0.31191        0.875
#              4          -0.27802        0.886
#              5          -0.25669        0.893
#              6          -0.24147        0.899
#              7          -0.22976        0.902
#              8          -0.22033        0.905
#              9          -0.21248        0.908
#             10          -0.20581        0.910
#             11          -0.20002        0.913
#             12          -0.19495        0.914
#             13          -0.19044        0.915
#             14          -0.18641        0.916
#             15          -0.18278        0.916
#             16          -0.17947        0.916
#             17          -0.17646        0.917
#             18          -0.17369        0.918
# ...

# %% [markdown]
# The final results of the testing indicate that the following features are useful in the name gender predictor, and best predicted using the Naive Bayes Classifier:
# - name length
# - the last two letters
# - the last three letters
# - the first three letters
#
# But how will the model perform on the reserved test set?

# %%
def gender_features(name):
    features = {}
    features['name_length'] = len(name)
    #features['last_letter'] = name[-1]
    #features['first_letter'] = name[0]
    features['last_two_letters'] = name[-2:]
    #features['first_two_letters'] = name[:2]
    features['last_three_letters'] = name[-3:]
    features['first_three_letters'] = name[:3]
    #for letter in 'abcdefghijklmnopqrstuvwxyz':
    #    features['count({})'.format(letter)] = name.lower().count(letter)
    #    features['has({})'.format(letter)] = (letter in name.lower())
    #   features['place({})'.format(letter)] = name.lower().find(letter)

    return features

featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]
test_set, dev_test_set, train_set = featuresets[:500], featuresets[500:1000], featuresets[1000:]

Bayes = nltk.NaiveBayesClassifier.train(train_set)
Max = nltk.MaxentClassifier.train(train_set)
Tree = nltk.DecisionTreeClassifier.train(train_set)
Bayes_accuracy = nltk.classify.accuracy(Bayes, test_set)
Max_accuracy = nltk.classify.accuracy(Max, test_set)
Tree_accuracy = nltk.classify.accuracy(Tree, test_set)
print(f'Bayes accuracy {Bayes_accuracy}')
print(f'Max entropy accuracy {Max_accuracy}')
print(f'Tree accuracy {Tree_accuracy}')
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.369
#              2          -0.38049        0.844
#              3          -0.31191        0.875
#              4          -0.27802        0.886
#              5          -0.25669        0.893
#              6          -0.24147        0.899
#              7          -0.22976        0.902
#              8          -0.22033        0.905
#              9          -0.21248        0.908
#             10          -0.20581        0.910
#             11          -0.20002        0.913
#             12          -0.19495        0.914
#             13          -0.19044        0.915
#             14          -0.18641        0.916
#             15          -0.18278        0.916
#             16          -0.17947        0.916
#             17          -0.17646        0.917
#             18          -0.17369        0.918
# ...

# %% [markdown]
# The result on the reserved test set is 83.2% with the Naive Bayse Classifier. This is lower than the dev_test_set, but still quite good. The reduction is likely going to be a result of overfitting to the specific training set, its specific randomization, and the specific names separated as the test set. That being said 82% is still getting more than 4 out of 5 genders correct.
#
# Below is an examination of the most useful features:

# %%
classifier.show_most_informative_features(20)
# Out:
# Most Informative Features
#         last_two_letters = 'na'           female : male   =    157.5 : 1.0
#         last_two_letters = 'la'           female : male   =     69.5 : 1.0
#         last_two_letters = 'ta'           female : male   =     43.4 : 1.0
#         last_two_letters = 'ld'             male : female =     39.6 : 1.0
#         last_two_letters = 'us'             male : female =     39.2 : 1.0
#         last_two_letters = 'ia'           female : male   =     37.1 : 1.0
#         last_two_letters = 'sa'           female : male   =     32.5 : 1.0
#         last_two_letters = 'rt'             male : female =     29.8 : 1.0
#         last_two_letters = 'rd'             male : female =     28.5 : 1.0
#         last_two_letters = 'do'             male : female =     26.2 : 1.0
#         last_two_letters = 'ra'           female : male   =     24.0 : 1.0
#         last_two_letters = 'ch'             male : female =     22.9 : 1.0
# ...

# %% [markdown]
# According to the first twenty most informative features, it was all the last two or three letters that are most informative. Additionally, the split is almost even as to the most informative features between male and female.
